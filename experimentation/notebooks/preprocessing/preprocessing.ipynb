# %%
import os
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Loading data

# %%
TOP_STOCKS_OPENING_CLOSING_PRICES = '../../../data/top_stocks_opening_closing_prices_data/'
top_stocks_opening_closing_prices_files = os.listdir(TOP_STOCKS_OPENING_CLOSING_PRICES)
top_stocks_opening_closing_prices_dfs = []
for filename in top_stocks_opening_closing_prices_files:
    if filename.endswith(".csv"):
        print(filename)
        df = pd.read_csv(TOP_STOCKS_OPENING_CLOSING_PRICES + filename)
        top_stocks_opening_closing_prices_dfs.append(df)
        continue
    else:
        continue
top_stocks_opening_closing_prices_dfs = pd.concat(top_stocks_opening_closing_prices_dfs, axis=0, ignore_index=True)
top_stocks_opening_closing_prices_dfs
# Out:
# top_stocks_opening_closing_prices_05-25-2023.csv
# top_stocks_opening_closing_prices_05-26-2023.csv
# top_stocks_opening_closing_prices_05-29-2023.csv
# top_stocks_opening_closing_prices_05-30-2023.csv
# top_stocks_opening_closing_prices_05-31-2023.csv
# top_stocks_opening_closing_prices_06-01-2023.csv
# top_stocks_opening_closing_prices_06-02-2023.csv
#    stock  opening_price  closing_price
# 0   NVDA        385.230         379.80
# 1     AI         30.500          28.41
# 2    AMD        117.305         120.35
# 3   PLTR         13.180          12.84
# 4   TSLA        186.540         184.47
# ..   ...            ...            ...
# 65  AVGO        790.640         812.00
# 66  SOFI          7.110           7.03
# 67    DG        162.200         166.12
# 68  META        272.660         272.61
# 69  CVNA         14.980          15.68
#
# [70 rows x 3 columns]

# %%
top_stocks_info_df = pd.DataFrame()
TOP_STOCKS_INFO_PATH = '../../../data/top_stocks_info_data/'
top_stocks_info_files = os.listdir(TOP_STOCKS_INFO_PATH)
top_stocks_info_dfs = []
for filename in top_stocks_info_files:
    if filename.endswith(".csv"):
        print(filename)
        df = pd.read_csv(TOP_STOCKS_INFO_PATH + filename)
        top_stocks_info_dfs.append(df)
        continue
    else:
        continue
top_stocks_info_df = pd.concat(top_stocks_info_dfs, axis=0, ignore_index=True)
top_stocks_info_df
# Out:
# top_stocks_info_05-25-2023.csv
# top_stocks_info_05-26-2023.csv
# top_stocks_info_05-29-2023.csv
# top_stocks_info_05-30-2023.csv
# top_stocks_info_05-31-2023.csv
# top_stocks_info_06-01-2023.csv
# top_stocks_info_06-02-2023.csv
#      timestamp  rank ticker                       name  mentions
# 0   05-25-2023     1   NVDA                     NVIDIA      3216  \
# 1   05-25-2023     2     AI                      C3 AI      1363
# 2   05-25-2023     3    AMD                        AMD       403
# 3   05-25-2023     6   PLTR                   Palantir       145
# 4   05-25-2023     7   TSLA                      Tesla       128
# ..         ...   ...    ...                        ...       ...
# 65  06-02-2023     8   AVGO                   Broadcom       113
# 66  06-02-2023     9   SOFI                       SoFi       108
# 67  06-02-2023    10     DG             Dollar General        90
# 68  06-02-2023    11   META  Meta Platforms (Facebook)        79
# 69  06-02-2023    12   CVNA                    Carvana        75
#
#     mentioning_users  upvotes  sentiment  rank_24h_ago  mentions_24h_ago
# 0             1370.0    30860       57.0             3               275  \
# 1              889.0     8328       68.0             1               327
# 2              259.0     2718       64.0             7                92
# 3               69.0      354       69.0             4               141
# 4              104.0      861       64.0             5               101
# ..               ...      ...        ...           ...               ...
# 65              74.0      274       58.0            26                31
# 66              62.0      403       72.0             5               218
# 67              65.0     2156       77.0           119                12
# 68              59.0      291       56.0            25                28
# 69              45.0      218       64.0            82                15
#
#         beta   epsTTM     peTTM    roeTTM  dividendYieldIndicatedAnnual
# 0   1.770654   1.7415  173.5333  18.66000                      0.052394  \
# 1   2.707838  -2.4261       NaN -22.98162                           NaN
# 2   1.812139   0.2412  131.9033   2.40000                           NaN
# 3   1.682084  -0.1246       NaN  -7.15660                           NaN
# 4   1.753238   3.3967   49.9490  27.90000                           NaN
# ..       ...      ...       ...       ...                           ...
# 65  1.109033  30.2074   26.3232  58.26000                      2.329261
# 66  1.943151  -0.2665       NaN  -1.40908                           NaN
# 67  0.359083  10.6825   18.2371  40.63000                      1.458050
# 68  1.392399   7.8343   31.6414  17.14000                           NaN
# 69  4.772926 -14.1389       NaN -32.94929                           NaN
#
#     totalDebt/totalEquityQuarterly  revenueGrowthTTMYoy
# 0                           0.4956               0.2200
# 1                           0.0000              14.6000
# 2                           0.0451              22.2000
# 3                           0.0000              20.5000
# 4                           0.0557              38.3400
# ..                             ...                  ...
# 65                          1.6852              20.7400
# 66                          1.1056             162.6023
# 67                          1.2648              10.5900
# 68                          0.0960              -1.9400
# 69                         27.0219              -9.6200
#
# [70 rows x 17 columns]

# %% [markdown]
# ### Joining prices and info datsets
#
# The opening_and_closing_prices data and top_stocks_info data would have to be concatanated.

# %%
training_data = pd.concat([top_stocks_opening_closing_prices_dfs, top_stocks_info_df], axis=1)

# %% [markdown]
# ### Computing target labels

# %%
training_data['label'] = (training_data['opening_price'] -
                          training_data['closing_price']).apply(lambda x: 1 if x > 0 else 0)

# %%
training_data['label'].value_counts()
# Out:
# label
# 0    44
# 1    26
# Name: count, dtype: int64

# %% [markdown]
# ### Renaming columns

# %%
training_data.rename(
    columns={'dividendYieldIndicatedAnnual': 'dividend_yield_annual',
             'epsTTM': 'earnings_per_share_ttm',
             'peTTM': 'price_to_equity_ttm',
             'roeTTM': 'return_on_equity_ttm',
             'totalDebt/totalEquityQuarterly': 'total_debt_to_equity_quarterly',
             'revenueGrowthTTMYoy': 'revenue_growth_ttm_yoy'
             }, inplace=True)

# %% [markdown]
# ### Creating new columns

# %%
training_data['dividend_exists'] = training_data['dividend_yield_annual'].apply(lambda x: 1 if x > 0 else 0)

# %%
training_data['change_in_rank'] = (
    (training_data['rank'] - training_data['rank_24h_ago'])/training_data['rank_24h_ago']
)

# %%
training_data['change_in_mentions'] = (
    (training_data['mentions'] - training_data['mentions_24h_ago'])/training_data['mentions_24h_ago']
)

# %%
training_data.isnull().sum()
# Out:
# stock                              0
# opening_price                      0
# closing_price                      0
# timestamp                          0
# rank                               0
# ticker                             0
# name                               0
# mentions                           0
# mentioning_users                   0
# upvotes                            0
# sentiment                          0
# rank_24h_ago                       0
# mentions_24h_ago                   0
# beta                               0
# earnings_per_share_ttm             0
# price_to_equity_ttm               19
# return_on_equity_ttm               0
# dividend_yield_annual             40
# total_debt_to_equity_quarterly     0
# revenue_growth_ttm_yoy             0
# label                              0
# dividend_exists                    0
# change_in_rank                     0
# change_in_mentions                 0
# dtype: int64

# %% [markdown]
# ### Dropping columns with duplication

# %%
training_data.drop(
    columns = ['stock'],
    inplace=True
)

# %% [markdown]
# ### Imputing values in columns

# %%
training_data['dividend_yield_annual'].replace(to_replace=np.nan, value=0, inplace=True)
training_data['price_to_equity_ttm'].replace(to_replace=np.nan, value=0, inplace=True)

# %% [markdown]
# ### Saving training and testing data

# %%
training_data.describe()
# Out:
#        opening_price  closing_price       rank     mentions  mentioning_users
# count      70.000000      70.000000  70.000000    70.000000         70.000000  \
# mean      191.463786     192.616429   6.971429   279.200000        175.457143
# std       186.616217     186.551978   3.615472   503.059267        267.851012
# min         5.240000       5.410000   1.000000    20.000000         19.000000
# 25%        32.970000      33.385000   4.000000    58.250000         43.500000
# 50%       144.345000     140.875000   7.500000   100.500000         68.500000
# 75%       310.595000     312.592500  10.000000   202.500000        122.250000
# max       835.120000     812.000000  13.000000  3216.000000       1370.000000
#
#             upvotes   sentiment  rank_24h_ago  mentions_24h_ago       beta
# count     70.000000   70.000000     70.000000         70.000000  70.000000  \
# mean    2618.742857   66.600000     25.071429        218.942857   1.672243
# std     5447.304686   11.160749     47.984394        471.981942   0.653953
# min       67.000000   38.000000      1.000000          1.000000   0.359083
# 25%      291.750000   58.250000      4.250000         20.500000   1.161613
# 50%      558.500000   67.000000      8.000000         50.000000   1.708573
# 75%     1599.000000   74.750000     24.750000        143.250000   1.812139
# max    30860.000000  100.000000    295.000000       3050.000000   4.772926
#
#        earnings_per_share_ttm  price_to_equity_ttm  return_on_equity_ttm
# count               70.000000            70.000000             70.000000  \
# mean                 4.192324            85.904277             23.786502
# std                  8.608851           219.614012             45.258641
# min                -14.138900             0.000000            -32.949290
# 25%                 -0.124600             0.000000             -1.409080
# 50%                  1.832850            29.405950             19.770000
# 75%                  5.885700           112.635425             28.365000
# max                 39.367900          1783.525900            165.720000
#
#        dividend_yield_annual  total_debt_to_equity_quarterly
# count              70.000000                       70.000000  \
# mean                0.582838                        0.883074
# std                 1.301282                        3.228772
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.045100
# 50%                 0.000000                        0.289850
# 75%                 0.555801                        0.969500
# max                 8.620690                       27.021900
#
#        revenue_growth_ttm_yoy      label  dividend_exists  change_in_rank
# count               70.000000  70.000000        70.000000       70.000000  \
# mean                21.607131   0.371429         0.428571       -0.185002
# std                 38.810489   0.486675         0.498445        0.498431
# min                -27.400000   0.000000         0.000000       -0.962712
# 25%                  2.140000   0.000000         0.000000       -0.578341
# 50%                 14.600000   0.000000         0.000000       -0.190909
# 75%                 22.200000   1.000000         1.000000        0.083333
# max                162.602300   1.000000         1.000000        1.000000
#
#        change_in_mentions
# count           70.000000
# mean             3.492647
# std              9.359938
# min             -0.625000
# 25%             -0.102564
# 50%              0.727221
# 75%              2.677390
# max             57.000000

# %%
training_data
# Out:
#     opening_price  closing_price   timestamp  rank ticker
# 0         385.230         379.80  05-25-2023     1   NVDA  \
# 1          30.500          28.41  05-25-2023     2     AI
# 2         117.305         120.35  05-25-2023     3    AMD
# 3          13.180          12.84  05-25-2023     6   PLTR
# 4         186.540         184.47  05-25-2023     7   TSLA
# ..            ...            ...         ...   ...    ...
# 65        790.640         812.00  06-02-2023     8   AVGO
# 66          7.110           7.03  06-02-2023     9   SOFI
# 67        162.200         166.12  06-02-2023    10     DG
# 68        272.660         272.61  06-02-2023    11   META
# 69         14.980          15.68  06-02-2023    12   CVNA
#
#                          name  mentions  mentioning_users  upvotes  sentiment
# 0                      NVIDIA      3216            1370.0    30860       57.0  \
# 1                       C3 AI      1363             889.0     8328       68.0
# 2                         AMD       403             259.0     2718       64.0
# 3                    Palantir       145              69.0      354       69.0
# 4                       Tesla       128             104.0      861       64.0
# ..                        ...       ...               ...      ...        ...
# 65                   Broadcom       113              74.0      274       58.0
# 66                       SoFi       108              62.0      403       72.0
# 67             Dollar General        90              65.0     2156       77.0
# 68  Meta Platforms (Facebook)        79              59.0      291       56.0
# 69                    Carvana        75              45.0      218       64.0
#
#     ...  earnings_per_share_ttm  price_to_equity_ttm  return_on_equity_ttm
# 0   ...                  1.7415             173.5333              18.66000  \
# 1   ...                 -2.4261               0.0000             -22.98162
# 2   ...                  0.2412             131.9033               2.40000
# 3   ...                 -0.1246               0.0000              -7.15660
# 4   ...                  3.3967              49.9490              27.90000
# ..  ...                     ...                  ...                   ...
# 65  ...                 30.2074              26.3232              58.26000
# 66  ...                 -0.2665               0.0000              -1.40908
# 67  ...                 10.6825              18.2371              40.63000
# 68  ...                  7.8343              31.6414              17.14000
# 69  ...                -14.1389               0.0000             -32.94929
#
#     dividend_yield_annual  total_debt_to_equity_quarterly
# 0                0.052394                          0.4956  \
# 1                0.000000                          0.0000
# 2                0.000000                          0.0451
# 3                0.000000                          0.0000
# 4                0.000000                          0.0557
# ..                    ...                             ...
# 65               2.329261                          1.6852
# 66               0.000000                          1.1056
# 67               1.458050                          1.2648
# 68               0.000000                          0.0960
# 69               0.000000                         27.0219
#
#     revenue_growth_ttm_yoy  label  dividend_exists  change_in_rank
# 0                   0.2200      1                1       -0.666667  \
# 1                  14.6000      1                0        1.000000
# 2                  22.2000      0                0       -0.571429
# 3                  20.5000      1                0        0.500000
# 4                  38.3400      1                0        0.400000
# ..                     ...    ...              ...             ...
# 65                 20.7400      0                1       -0.692308
# 66                162.6023      1                0        0.800000
# 67                 10.5900      0                1       -0.915966
# 68                 -1.9400      1                0       -0.560000
# 69                 -9.6200      0                0       -0.853659
#
#     change_in_mentions
# 0            10.694545
# 1             3.168196
# 2             3.380435
# 3             0.028369
# 4             0.267327
# ..                 ...
# 65            2.645161
# 66           -0.504587
# 67            6.500000
# 68            1.821429
# 69            4.000000
#
# [70 rows x 23 columns]

# %%
training_data.columns
# Out:
# Index(['opening_price', 'closing_price', 'timestamp', 'rank', 'ticker', 'name',
#        'mentions', 'mentioning_users', 'upvotes', 'sentiment', 'rank_24h_ago',
#        'mentions_24h_ago', 'beta', 'earnings_per_share_ttm',
#        'price_to_equity_ttm', 'return_on_equity_ttm', 'dividend_yield_annual',
#        'total_debt_to_equity_quarterly', 'revenue_growth_ttm_yoy', 'label',
#        'dividend_exists', 'change_in_rank', 'change_in_mentions'],
#       dtype='object')

# %%
training_data.to_csv('../../../data/train_test_data.csv', index=False)
